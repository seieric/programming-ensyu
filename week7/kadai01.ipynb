# %% [markdown]
# # 第07回 課題1

# %%
def legendre(n, x):
    if n == 0:
        return 1
    elif n == 1:
        return x
    return ((2 * n - 1) * x * legendre(n - 1, x) - (n - 1) * legendre(n - 2, x)) / n

# %%
print(legendre(16, 0.5))
print(legendre(32, 0.7))
# Out:
# -0.14985513547435403
# 0.16517573473031175
