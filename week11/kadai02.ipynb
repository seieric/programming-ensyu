# %%
import numpy as np

size = 1000000

x = np.random.uniform(-2,2,size)
y = np.random.uniform(-2,2,size)
z = np.random.uniform(-2,2,size)

flat = x + y + 2 * z - 1 # 平面
obj = 2 * x**2 + 3 * y**2 + z**2 - 4 # 楕円球

target = (obj <= 0) & (flat >= 0)

64 * len(target[target == True]) / size
# Out:
# 4.521216
